# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from analytics import (
    calculate_cagr, calculate_mdd, calculate_sharpe_ratio, 
    calculate_annualized_volatility, calculate_sortino_ratio
) 
from backtesting import (
    generate_crossover_signals, 
    backtest_strategy, 
    analyze_strategy
)

# %%
from data_loader import load_data
nifty = pd.read_csv("C:/Users/Lenovo/OneDrive/Desktop/Project/Market Data Analyzer/data/nifty.csv")

# %%
strategy_df = generate_crossover_signals(nifty.copy(), 20, 50)
final_df = backtest_strategy(strategy_df)
analyze_strategy(nifty.copy(), final_df)
# Out:
# C:\Users\Lenovo\OneDrive\Desktop\Project\Market Data Analyzer\src\backtesting.py:50: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Position'] = df['Signal'].replace(to_replace=-1, value=0).fillna(method='ffill')
# C:\Users\Lenovo\OneDrive\Desktop\Project\Market Data Analyzer\src\backtesting.py:51: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Position'].fillna(0, inplace=True)
# ...
